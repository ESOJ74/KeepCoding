# %% [markdown]
# # Gestión de paquetes
#
# En R hay multitud de paquetes que pueden ampliar su funcionalidad con nuevas funciones.
# Existe un repositorio oficial en [CRAN](https://cran.r-project.org/web/packages/index.html)
#
# R permite gestionar los paquetes mediante los comandos:
# * install.packages(pkgs, respos): Instala nuevos paquetes.
# * installed.packages(): Muestra los paquetes instalados.
# * remove.packages(pkgs) : Borra los paquetes indicados.
# * library(pkg) : Carga en memoria el paquete indicado.

# %% [markdown]
# # Gráficos
#
# Ya hemos visto como realizar gráficos con *plot*. Existe una librería más completa llamada ggplot2.

# %%
# instalación
#install.packages(c('ggplot2'), repos='https://cran.rstudio.com/')

# %%
library("ggplot2")
options(repr.plot.height=6,repr.plot.width=8 , repr.plot.res = 200)

# %% [markdown]
# #### Ejemplo de gráficas

# %%
valX <- seq(-5,5, by=0.5)
valY <- valX+valX^2+valX^3

mydf <- data.frame(dfx=valX, dfy=valY)
head(mydf)
# Out:
#   dfx  dfy
# 1 -5.0 -105.000
# 2 -4.5  -75.375
# 3 -4.0  -52.000
# 4 -3.5  -34.125
# 5 -3.0  -21.000
# 6 -2.5  -11.875

# %%
summary(mydf)
# Out:
#       dfx            dfy
#  Min.   :-5.0   Min.   :-105.000
#  1st Qu.:-2.5   1st Qu.: -11.875
#  Median : 0.0   Median :   0.000
#  Mean   : 0.0   Mean   :   9.167
#  3rd Qu.: 2.5   3rd Qu.:  24.375
#  Max.   : 5.0   Max.   : 155.000

# %%
#ggplot crea un objeto para representar gráficos
#geom_line crea una linea sobre el objeto ggplot
#geom_point muestra los puntos sobre el objeto ggplot
#El objeto aes, indica que columnas vamos a usar para las coordenadas X e Y

ggplot(data=mydf, aes(x=dfx, y=dfy))+geom_line(color='blue')+geom_point(colour='red', size=5)
# Out:
# plot without title

# %%
mydf$type <- "function 1"
head(mydf)
# Out:
#   dfx  dfy      type
# 1 -5.0 -105.000 function 1
# 2 -4.5  -75.375 function 1
# 3 -4.0  -52.000 function 1
# 4 -3.5  -34.125 function 1
# 5 -3.0  -21.000 function 1
# 6 -2.5  -11.875 function 1

# %%
mydf2 <- data.frame(dfx=valX, dfy=1+2*valX+3*valX^2, type='function 2')
mydf2 <- rbind(mydf, mydf2)
head(mydf2)
tail(mydf2)
# Out:
#   dfx  dfy      type
# 1 -5.0 -105.000 function 1
# 2 -4.5  -75.375 function 1
# 3 -4.0  -52.000 function 1
# 4 -3.5  -34.125 function 1
# 5 -3.0  -21.000 function 1
# 6 -2.5  -11.875 function 1
#    dfx dfy   type
# 37 2.5 24.75 function 2
# 38 3.0 34.00 function 2
# 39 3.5 44.75 function 2
# 40 4.0 57.00 function 2
# 41 4.5 70.75 function 2
# 42 5.0 86.00 function 2

# %%
(idx<-sort(sample(1:nrow(mydf2),5)))
mydf2[idx,]
# Out:
# [1] 11 12 16 30 39
#    dfx  dfy    type
# 11  0.0  0.000 function 1
# 12  0.5  0.875 function 1
# 16  2.5 24.375 function 1
# 30 -1.0  2.000 function 2
# 39  3.5 44.750 function 2

# %%
mydf2$type <- factor(mydf2$type)

# %%
summary(mydf2)
# Out:
#       dfx            dfy                    type
#  Min.   :-5.0   Min.   :-105.0000   function 1:21
#  1st Qu.:-2.5   1st Qu.:   0.1875   function 2:21
#  Median : 0.0   Median :   9.8750
#  Mean   : 0.0   Mean   :  18.8333
#  3rd Qu.: 2.5   3rd Qu.:  40.5000
#  Max.   : 5.0   Max.   : 155.0000

# %%
g <- ggplot(data=mydf2,aes(x=dfx,y=dfy,color=type))

# %%
summary(g)
# Out:
# data: dfx, dfy, type [42x3]
# mapping:  x = ~dfx, y = ~dfy, colour = ~type
# faceting: <ggproto object: Class FacetNull, Facet, gg>
#     compute_layout: function
#     draw_back: function
#     draw_front: function
#     draw_labels: function
#     draw_panels: function
#     finish_data: function
#     init_scales: function
#     map_data: function
#     params: list
#     setup_data: function
#     setup_params: function
#     shrink: TRUE
#     train_scales: function
#     vars: function
#     super:  <ggproto object: Class FacetNull, Facet, gg>

# %%
g <- g + geom_line() + geom_point()

# %%
summary(g)
# Out:
# data: dfx, dfy, type [42x3]
# mapping:  x = ~dfx, y = ~dfy, colour = ~type
# faceting: <ggproto object: Class FacetNull, Facet, gg>
#     compute_layout: function
#     draw_back: function
#     draw_front: function
#     draw_labels: function
#     draw_panels: function
#     finish_data: function
#     init_scales: function
#     map_data: function
#     params: list
#     setup_data: function
#     setup_params: function
#     shrink: TRUE
#     train_scales: function
#     vars: function
#     super:  <ggproto object: Class FacetNull, Facet, gg>
# -----------------------------------
# geom_line: na.rm = FALSE, orientation = NA
# stat_identity: na.rm = FALSE
# position_identity
#
# geom_point: na.rm = FALSE
# stat_identity: na.rm = FALSE
# position_identity

# %%
g
# Out:
# plot without title

# %% [markdown]
# R tiene varios datasets incorporados. En este caso vamos a usar el dataset de iris.
#
# Este conjunto de datos de iris da medidas en centímetros de las variables longitud y anchura del sépalo, y de los pétalos, para 50 flores de cada una de las 3 especies de iris. Las especies son _Iris setosa_, _versicolor_ y _virginica_.
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/5/56/Kosaciec_szczecinkowaty_Iris_setosa.jpg/220px-Kosaciec_szczecinkowaty_Iris_setosa.jpg)

# %%
summary(iris)
# Out:
#   Sepal.Length    Sepal.Width     Petal.Length    Petal.Width
#  Min.   :4.300   Min.   :2.000   Min.   :1.000   Min.   :0.100
#  1st Qu.:5.100   1st Qu.:2.800   1st Qu.:1.600   1st Qu.:0.300
#  Median :5.800   Median :3.000   Median :4.350   Median :1.300
#  Mean   :5.843   Mean   :3.057   Mean   :3.758   Mean   :1.199
#  3rd Qu.:6.400   3rd Qu.:3.300   3rd Qu.:5.100   3rd Qu.:1.800
#  Max.   :7.900   Max.   :4.400   Max.   :6.900   Max.   :2.500
#        Species
#  setosa    :50
#  versicolor:50
#  virginica :50

# %%
iris[sample(1:nrow(iris),5),]
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 53  6.9          3.1         4.9          1.5         versicolor
# 102 5.8          2.7         5.1          1.9         virginica
# 96  5.7          3.0         4.2          1.2         versicolor
# 113 6.8          3.0         5.5          2.1         virginica
# 140 6.9          3.1         5.4          2.1         virginica

# %%
ggplot(data=iris,aes(x=Species, y=Sepal.Length,color=Species))+geom_boxplot()+
 scale_color_discrete(name="Especie")+xlab('Especie')+ylab('Longitud Sepalo')
# Out:
# plot without title

# %%
ggplot(data=iris,aes(x=Sepal.Width, y =Sepal.Length, color=Species, shape=Species))+
  geom_point(alpha=0.7)+
  labs(color = "Especies", shape="Especies")   +
  #geom_jitter(size=3)+  
  theme_bw()+ xlab("Anchura del sépalo")+ylab("Longitud del sépalo")+
  ggtitle("Comparación del ancho y longitud del sépalo")
# Out:
# plot without title

# %% [markdown]
# ### Ejemplo con los seguros de coche
#
# Partimos del dataset de automóviles y seguros que podemos descargar de:
#
# https://archive.ics.uci.edu/ml/datasets/Automobile
#
# Al igual que usamos en el capítulo 1.

# %%
autos<-read.csv("./data//imports-85.data", col.names = c("risk", "normalized_losses", 
                                                         "make", "fuel_type", "aspiration",
           "num_doors", "body_style", "drive_wheels", "engine_location",
           "wheel_base", "length", "width", "height", "curb_weight",
           "engine_type", "num_cylinders", "engine_size", "fuel_system",
           "bore", "stroke", "compression_ratio", "horsepower", "peak_rpm",
           "city_mpg", "highway_mpg", "price"))

# %%
ggplot(data=autos, aes(x=length, y=width))+
 geom_point(aes(size=height),alpha=0.4)+
 scale_size_continuous(name="Altura")+
 xlab("Longitud del coche")+
 ylab("Ancho del coche")
# Out:
# plot without title

# %% [markdown]
# Recomendada la visualización de Hans Rosling:
# https://www.ted.com/talks/hans_rosling_shows_the_best_stats_you_ve_ever_seen

# %%
ggplot(data=autos, aes(x=body_style, y=length, color=body_style))+geom_boxplot()
# Out:
# plot without title

# %%
summary(autos[autos$body_style=='convertible','length'])
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   159.3   168.8   168.9   170.7   176.2   180.3

# %%
#?geom_boxplot

# %%
unique(autos$body_style)
# Out:
# [1] "convertible" "hatchback"   "sedan"       "wagon"       "hardtop"

# %% [markdown]
# ## Ejemplo con las estrellas
#
# *Se denomina [secuencia principal](https://es.wikipedia.org/wiki/Secuencia_principal) a la región del diagrama de Hertzsprung-Russell en la que se encuentran la mayor parte de las estrellas. Es una banda continua y distintiva de estrellas que aparece en las parcelas de color estelar versus brillo. Las estrellas en esta banda son conocidas como estrellas de secuencia principal o estrellas enanas. Por esta razón, estas estrellas son llamadas de secuencia principal. La secuencia principal termina entre las estrellas más frías de esta banda o curva que son las enanas rojas, de masa baja y comienza entre las bandas de las estrellas que se ubican hacia las altas temperaturas que son las supermasivas gigantes azules. El diagrama H-R es un diagrama estadístico que muestra la temperatura efectiva de las estrellas en función de su luminosidad. Otras regiones del diagrama están ocupadas por estrellas gigantes de corta vida y evolución rápida o por enanas blancas muy estables.*

# %%
library('dslabs')
data(stars)

# %%
head(stars)
# Out:
#   star           magnitude temp type
# 1 Sun             4.8      5840 G
# 2 SiriusA         1.4      9620 A
# 3 Canopus        -3.1      7400 F
# 4 Arcturus       -0.4      4590 K
# 5 AlphaCentauriA  4.3      5840 G
# 6 Vega            0.5      9900 A

# %%
sun_star <- stars[stars=="Sun",]
sun_star
# Out:
#   star magnitude temp type
# 1 Sun  4.8       5840 G

# %%
ggplot(stars, aes(x=temp, y=magnitude))+
    geom_point(aes(color=temp))+scale_color_gradientn(colours=rainbow(5, rev=FALSE))+
    geom_point(x=sun_star$temp,y=sun_star$magnitude, size=10, shape=1)+
    #scale_x_reverse()+scale_y_reverse()+
    ggtitle("Diagrama HR")
# Out:
# plot without title

# %% [markdown]
# ## COVID-19
#
#
# Vamos a descargarnos los datos del repositorio de la universidad Johns Hopkins donde se almacena la cantidad de casos acumulados de COVID

# %%
covid_url<-'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'

df<-read.csv(url(covid_url))
head(df)
# Out:
#   Province.State Country.Region      Lat       Long      X1.22.20 X1.23.20
# 1                Afghanistan          33.93911  67.70995 0        0
# 2                Albania              41.15330  20.16830 0        0
# 3                Algeria              28.03390   1.65960 0        0
# 4                Andorra              42.50630   1.52180 0        0
# 5                Angola              -11.20270  17.87390 0        0
# 6                Antigua and Barbuda  17.06080 -61.79640 0        0
#   X1.24.20 X1.25.20 X1.26.20 X1.27.20 ⋯ X9.25.21 X9.26.21 X9.27.21 X9.28.21
# 1 0        0        0        0        ⋯ 154960   154960   155072   155093
# 2 0        0        0        0        ⋯ 167354   167893   168188   168782
# 3 0        0        0        0        ⋯ 202574   202722   202877   203045
# 4 0        0        0        0        ⋯  15167    15167    15189    15192
# 5 0        0        0        0        ⋯  54795    55121    55583    56040
# 6 0        0        0        0        ⋯   2902     2923     2923     3160
#   X9.29.21 X9.30.21 X10.1.21 X10.2.21 X10.3.21 X10.4.21
# 1 155128   155174   155191   155191   155191   155287
# 2 169462   170131   170778   171327   171794   171794
# 3 203198   203359   203517   203657   203789   203915
# 4  15209    15222    15222    15222    15222    15267
# 5  56583    56583    58076    58603    58943    58943
# 6   3188     3231     3336     3403     3503     3503

# %%
df$Lat<-NULL
df$Long<-NULL
tail(df)
# Out:
#     Province.State Country.Region     X1.22.20 X1.23.20 X1.24.20 X1.25.20
# 274                Venezuela          0        0        0        0
# 275                Vietnam            0        2        2        2
# 276                West Bank and Gaza 0        0        0        0
# 277                Yemen              0        0        0        0
# 278                Zambia             0        0        0        0
# 279                Zimbabwe           0        0        0        0
#     X1.26.20 X1.27.20 X1.28.20 X1.29.20 ⋯ X9.25.21 X9.26.21 X9.27.21 X9.28.21
# 274 0        0        0        0        ⋯ 362040   362040   363300   366150
# 275 2        2        2        2        ⋯ 746678   756689   766051   770640
# 276 0        0        0        0        ⋯ 395677   396746   398946   400649
# 277 0        0        0        0        ⋯   8891     8934     8988     9016
# 278 0        0        0        0        ⋯ 208829   208857   208867   208912
# 279 0        0        0        0        ⋯ 129505   129625   129919   130272
#     X9.29.21 X9.30.21 X10.1.21 X10.2.21 X10.3.21 X10.4.21
# 274 367672   368968   368968   370368   373332   373332
# 275 779398   790755   797712   803202   808578   813961
# 276 402255   403716   405056   405780   406652   408211
# 277   9039     9067     9111     9139     9139     9214
# 278 209002   209046   209114   209142   209163   209172
# 279 130485   130820   131028   131094   131129   131129

# %%
library(reshape2)
df_cov<-melt(df,id.vars=c("Province.State","Country.Region"))
tail(df_cov)
dim(df_cov)
# Out:
#        Province.State Country.Region     variable value
# 173533                Venezuela          X10.4.21 373332
# 173534                Vietnam            X10.4.21 813961
# 173535                West Bank and Gaza X10.4.21 408211
# 173536                Yemen              X10.4.21   9214
# 173537                Zambia             X10.4.21 209172
# 173538                Zimbabwe           X10.4.21 131129
# [1] 173538      4

# %%
tail(df_cov[df_cov$Country.Region=='Venezuela',])
# Out:
#        Province.State Country.Region variable value
# 172138                Venezuela      X9.29.21 367672
# 172417                Venezuela      X9.30.21 368968
# 172696                Venezuela      X10.1.21 368968
# 172975                Venezuela      X10.2.21 370368
# 173254                Venezuela      X10.3.21 373332
# 173533                Venezuela      X10.4.21 373332

# %%
df_cov$fecha<-as.POSIXct(df_cov$variable, format='X%m.%d.%y')
head(df_cov)
# Out:
#   Province.State Country.Region      variable value fecha
# 1                Afghanistan         X1.22.20 0     2020-01-22
# 2                Albania             X1.22.20 0     2020-01-22
# 3                Algeria             X1.22.20 0     2020-01-22
# 4                Andorra             X1.22.20 0     2020-01-22
# 5                Angola              X1.22.20 0     2020-01-22
# 6                Antigua and Barbuda X1.22.20 0     2020-01-22

# %%
df_country<-df_cov[df_cov$Country.Region=="Spain" | df_cov$Country.Region=="Italy",]
tail(df_country)
# Out:
#        Province.State Country.Region variable value   fecha
# 172855                Italy          X10.2.21 4679067 2021-10-02
# 172939                Spain          X10.2.21 4961128 2021-10-02
# 173134                Italy          X10.3.21 4682034 2021-10-03
# 173218                Spain          X10.3.21 4961128 2021-10-03
# 173413                Italy          X10.4.21 4683646 2021-10-04
# 173497                Spain          X10.4.21 4965399 2021-10-04

# %%
ggplot(df_country, aes(x=fecha,y=value,color=Country.Region))+
 geom_line(size=2)+ylab("Numero de casos")+theme(text=element_text(size=15))+theme_bw()
# Out:
# plot without title
